# %%
import pandas as pd
import requests

# %%
# !pip install pandas
# !pip install requests

# %%
https://api.themoviedb.org/3/movie/top_rated?api_key=ee270154daf9c270d373f1de454ebfe2&language=en-US&page=1'

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=ee270154daf9c270d373f1de454ebfe2&language=en-US&page=1')
response
# Out:
# <Response [200]>

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/avedvodAZUcwqevBfm8p4G2NziQ.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
#    'overview': 'Imprisoned in the 1940s for the double murder of his wife and her lover, upstanding banker Andy Dufresne begins a new life at the Shawshank prison, where he puts his accounting skills to work for an amoral warden. During his long stretch in prison, Dufresne comes to be admired by the other inmates -- including an older prisoner named Red -- for his integrity and unquenchable sense of hope.',
#    'popularity': 162.491,
#    'poster_path': '/9cqNxx0GxF0bflZmeSMuL5tnGzr.jpg',
#    'release_date': '1994-09-23',
#    'title': 'The Shawshank Redemption',
#    'video': False,
#    'vote_average': 8.705,
#    'vote_count': 26660},
#   {'adult': False,
#    'backdrop_path': '/tmU7GeKVybMWFButWEGl2M4GeiP.jpg',
#    'genre_ids': [18, 80],
# ...

# %%
temp_df = pd.DataFrame(response.json())
temp_df
# Out:
#     page                                            results  total_pages  \
# 0      1  {'adult': False, 'backdrop_path': '/avedvodAZU...          478
# 1      1  {'adult': False, 'backdrop_path': '/tmU7GeKVyb...          478
# 2      1  {'adult': False, 'backdrop_path': '/kGzFbGhp99...          478
# 3      1  {'adult': False, 'backdrop_path': '/zb6fM1CX41...          478
# 4      1  {'adult': False, 'backdrop_path': '/qqHQsStV6e...          478
# 5      1  {'adult': False, 'backdrop_path': '/m4TUa2ciEW...          478
# 6      1  {'adult': False, 'backdrop_path': '/90ez6ArvpO...          478
# 7      1  {'adult': False, 'backdrop_path': '/dqK9Hag105...          478
# 8      1  {'adult': False, 'backdrop_path': '/8eihUxjQsJ...          478
# 9      1  {'adult': False, 'backdrop_path': '/vxJ08Svwom...          478
# 10     1  {'adult': False, 'backdrop_path': '/dIWwZW7dJJ...          478
# 11     1  {'adult': False, 'backdrop_path': '/suaEOtk1N1...          478
# ...

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date']]

# %%
temp_df
# Out:
#          id                                          title  \
# 0       278                       The Shawshank Redemption
# 1       238                                  The Godfather
# 2       240                          The Godfather Part II
# 3       424                               Schindler's List
# 4       389                                   12 Angry Men
# 5       129                                  Spirited Away
# 6     19404                    Dilwale Dulhania Le Jayenge
# 7       155                                The Dark Knight
# 8    496243                                       Parasite
# 9       497                                 The Green Mile
# 10   372058                                     Your Name.
# 11      680                                   Pulp Fiction
# 12      122  The Lord of the Rings: The Return of the King
# 13       13                                   Forrest Gump
# 14  1084736                      The Count of Monte-Cristo
# ...

# %%
temp_df
# Out:
#         id                                          title  \
# 0      278                       The Shawshank Redemption
# 1      238                                  The Godfather
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4      389                                   12 Angry Men
# 5      129                                  Spirited Away
# 6    19404                    Dilwale Dulhania Le Jayenge
# 7      155                                The Dark Knight
# 8   496243                                       Parasite
# 9      497                                 The Green Mile
# 10  372058                                     Your Name.
# 11     680                                   Pulp Fiction
# 12     122  The Lord of the Rings: The Return of the King
# 13      13                                   Forrest Gump
# 14     429                 The Good, the Bad and the Ugly
# ...

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.DataFrame()
for i in range(1,478):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=53c6609e87e69fc3b340777f7b4fcc13&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.concat(temp_df,ignore_index=True)
df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-9f9743056d99> in <cell line: 2>()
#       3     response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=53c6609e87e69fc3b340777f7b4fcc13&language=en-US&page={}'.format(i))
#       4     temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# ----> 5     df = df.concat(temp_df,ignore_index=True)
#       6 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
dfs = []
for i in range(1, 479):
    response = requests.get(f'https://api.themoviedb.org/3/movie/top_rated?api_key=53c6609e87e69fc3b340777f7b4fcc13&language=en-US&page={i}')
    temp_df = pd.DataFrame(response.json()['results'])[['id', 'title', 'overview', 'release_date']]
    dfs.append(temp_df)
    df = pd.concat(dfs, ignore_index=True)

# %% [markdown]
# Weatrher api from rapid api

# %%
df
# Out:
#           id                                   title  \
# 0        278                The Shawshank Redemption
# 1        238                           The Godfather
# 2        240                   The Godfather Part II
# 3        424                        Schindler's List
# 4        389                            12 Angry Men
# ...      ...                                     ...
# 9555  238930                             Brain Drain
# 9556    9760                              Epic Movie
# 9557   94365  The Human Centipede 3 (Final Sequence)
# 9558    9544                              FearDotCom
# 9559  485774                          The Open House
#
#                                                overview release_date
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# ...

# %%
import requests

url = "https://open-weather13.p.rapidapi.com/city/latlon/30.438/-89.1028"

headers = {
	"x-rapidapi-key": "a17e7a81c1msha0bef81b778a41ap143920jsnae5ae100879f",
	"x-rapidapi-host": "open-weather13.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'coord': {'lon': -89.1028, 'lat': 30.438}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 307.51, 'feels_like': 314.51, 'temp_min': 305.9, 'temp_max': 308.15, 'pressure': 1016, 'humidity': 56, 'sea_level': 1016, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 2.68, 'deg': 340}, 'clouds': {'all': 20}, 'dt': 1723654938, 'sys': {'type': 2, 'id': 2015175, 'country': 'US', 'sunrise': 1723634580, 'sunset': 1723682352}, 'timezone': -18000, 'id': 4450687, 'name': 'West Gulfport', 'cod': 200}

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 9535   17473                  The Room
# 9536    8046                     Gigli
# 9537    7278         Meet the Spartans
# 9538  505423                    Wounds
# 9539  419507        Fuga da Reuma Park
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# ...

# %%
df.shape

# %%
df.to_csv('movies.csv')
